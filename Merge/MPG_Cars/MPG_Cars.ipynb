# %%
# import the necessary libraries
import pandas as pd
import numpy as np

# %%
# load dataset
cars1 = pd.read_csv('cars1.csv')
cars2 = pd.read_csv('cars2.csv')

# %%
# it seems our first dataset has some unnamed blank columns
cars1 = cars1.iloc[:, :9]
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# what is the number of observation in each dataset?
# car1 shape
cars1.shape[0]
# Out:
# 198

# %%
# car2 shape
cars2.shape[0]
# Out:
# 200

# %%
# join cars1 and cars2 into a single dataframe called cars
cars = pd.merge(cars1, cars2, on='mpg', how='inner')
cars.head()
# Out:
#     mpg  cylinders_x  displacement_x horsepower_x  weight_x  acceleration_x  \
# 0  18.0            8             307          130      3504            12.0
# 1  18.0            8             318          150      3436            11.0
# 2  18.0            6             199           97      2774            15.5
# 3  18.0            6             232          100      3288            15.5
# 4  18.0            6             258          110      2962            13.5
#
#    model_x  origin_x                       car_x  cylinders_y  displacement_y  \
# 0       70         1   chevrolet chevelle malibu            6             250
# 1       70         1          plymouth satellite            6             250
# 2       70         1                  amc hornet            6             250
# 3       71         1                 amc matador            6             250
# 4       71         1  amc hornet sportabout (sw)            6             250
#
#   horsepower_y  weight_y  acceleration_y  model_y  origin_y              car_y
# 0           78      3574            21.0       76         1  ford granada ghia
# 1           78      3574            21.0       76         1  ford granada ghia
# 2           78      3574            21.0       76         1  ford granada ghia
# 3           78      3574            21.0       76         1  ford granada ghia
# 4           78      3574            21.0       76         1  ford granada ghia

# %%
# creating a new column called owners by create a random number Series from 15,000 to 73,000
owner_column = np.random.randint(low=15000, high=73000, size=(344, 1))

# %%
# adding it to the new dataframe
cars['owners'] = owner_column
cars.head(20)
# Out:
#      mpg  cylinders_x  displacement_x horsepower_x  weight_x  acceleration_x  \
# 0   18.0            8             307          130      3504            12.0
# 1   18.0            8             318          150      3436            11.0
# 2   18.0            6             199           97      2774            15.5
# 3   18.0            6             232          100      3288            15.5
# 4   18.0            6             258          110      2962            13.5
# 5   18.0            6             250           88      3139            14.5
# 6   18.0            4             121          112      2933            14.5
# 7   18.0            6             225          105      3121            16.5
# 8   18.0            6             232          100      2945            16.0
# 9   18.0            6             250           88      3021            16.5
# 10  18.0            6             232          100      2789            15.0
# 11  18.0            3              70           90      2124            13.5
# 12  18.0            6             225          105      3613            16.5
# 13  18.0            6             250          105      3459            16.0
# 14  18.0            6             225           95      3785            19.0
# 15  18.0            6             171           97      2984            14.5
# 16  15.0            8             350          165      3693            11.5
# 17  15.0            8             429          198      4341            10.0
# 18  15.0            8             390          190      3850             8.5
# 19  15.0            8             383          170      3563            10.0
#
#     model_x  origin_x                       car_x  cylinders_y  \
# 0        70         1   chevrolet chevelle malibu            6
# 1        70         1          plymouth satellite            6
# 2        70         1                  amc hornet            6
# 3        71         1                 amc matador            6
# 4        71         1  amc hornet sportabout (sw)            6
# 5        71         1                ford mustang            6
# 6        72         2             volvo 145e (sw)            6
# 7        73         1            plymouth valiant            6
# 8        73         1                  amc hornet            6
# 9        73         1               ford maverick            6
# 10       73         1                 amc gremlin            6
# 11       73         3                   maxda rx3            6
# 12       74         1  plymouth satellite sebring            6
# 13       75         1              chevrolet nova            6
# 14       75         1               plymouth fury            6
# 15       75         1                  ford pinto            6
# 16       70         1           buick skylark 320            8
# 17       70         1            ford galaxie 500            8
# 18       70         1          amc ambassador dpl            8
# 19       70         1         dodge challenger se            8
#
#     displacement_y horsepower_y  weight_y  acceleration_y  model_y  origin_y  \
# 0              250           78      3574            21.0       76         1
# 1              250           78      3574            21.0       76         1
# 2              250           78      3574            21.0       76         1
# 3              250           78      3574            21.0       76         1
# 4              250           78      3574            21.0       76         1
# 5              250           78      3574            21.0       76         1
# 6              250           78      3574            21.0       76         1
# 7              250           78      3574            21.0       76         1
# 8              250           78      3574            21.0       76         1
# 9              250           78      3574            21.0       76         1
# 10             250           78      3574            21.0       76         1
# 11             250           78      3574            21.0       76         1
# 12             250           78      3574            21.0       76         1
# 13             250           78      3574            21.0       76         1
# 14             250           78      3574            21.0       76         1
# 15             250           78      3574            21.0       76         1
# 16             302          130      4295            14.9       77         1
# 17             302          130      4295            14.9       77         1
# 18             302          130      4295            14.9       77         1
# 19             302          130      4295            14.9       77         1
#
#                       car_y  owners
# 0         ford granada ghia   43905
# 1         ford granada ghia   60112
# 2         ford granada ghia   63779
# 3         ford granada ghia   67722
# 4         ford granada ghia   59008
# 5         ford granada ghia   26242
# 6         ford granada ghia   57745
# 7         ford granada ghia   43783
# 8         ford granada ghia   24426
# 9         ford granada ghia   64363
# 10        ford granada ghia   30508
# 11        ford granada ghia   23970
# 12        ford granada ghia   64386
# 13        ford granada ghia   40184
# 14        ford granada ghia   52074
# 15        ford granada ghia   60593
# 16  mercury cougar brougham   70373
# 17  mercury cougar brougham   22664
# 18  mercury cougar brougham   53286
# 19  mercury cougar brougham   57611
